# %%
# Importing all required packages
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
# Data viz lib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
Df = pd.read_csv('employee.csv')

# %%
Df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
Df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
Df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
ADf= Df.loc[Df['Attrition'] == "No"]

# %%
ADf.head()
ADf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1233 entries, 1 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1233 non-null   int64
#  1   Attrition                 1233 non-null   object
#  2   BusinessTravel            1233 non-null   object
#  3   DailyRate                 1233 non-null   int64
#  4   Department                1233 non-null   object
#  5   DistanceFromHome          1233 non-null   int64
#  6   Education                 1233 non-null   int64
#  7   EducationField            1233 non-null   object
#  8   EmployeeCount             1233 non-null   int64
#  9   EmployeeNumber            1233 non-null   int64
#  10  EnvironmentSatisfaction   1233 non-null   int64
#  11  Gender                    1233 non-null   object
#  12  HourlyRate                1233 non-null   int64
#  13  JobInvolvement            1233 non-null   int64
# ...

# %%
newdf = ADf.loc[((ADf['YearsAtCompany']>=5) & (ADf['YearsSinceLastPromotion']>=3) &((ADf['JobSatisfaction']<=3) | ADf['WorkLifeBalance']<=3))]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 3 to 1462
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       317 non-null    int64
#  1   Attrition                 317 non-null    object
#  2   BusinessTravel            317 non-null    object
#  3   DailyRate                 317 non-null    int64
#  4   Department                317 non-null    object
#  5   DistanceFromHome          317 non-null    int64
#  6   Education                 317 non-null    int64
#  7   EducationField            317 non-null    object
#  8   EmployeeCount             317 non-null    int64
#  9   EmployeeNumber            317 non-null    int64
#  10  EnvironmentSatisfaction   317 non-null    int64
#  11  Gender                    317 non-null    object
#  12  HourlyRate                317 non-null    int64
#  13  JobInvolvement            317 non-null    int64
# ...

# %%
Q1= newdf.loc[(newdf['JobRole']=="Research Scientist")&(newdf['PerformanceRating']>=4)&(newdf['JobSatisfaction']>=3)&(newdf['EducationField']!="Medical")]

# %%
Q1.head()
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 875    44        No  Travel_Rarely        200  Research & Development
# 1320   42        No     Non-Travel        355  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 875                 29          4             Other              1
# 1320                10          4  Technical Degree              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 875             1225                        4   Male          32
# 1320            1854                        3   Male          38
#
#       JobInvolvement  JobLevel             JobRole  JobSatisfaction  \
# 875                3         2  Research Scientist                4
# 1320               3         1  Research Scientist                3
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# ...

# %%
# Answer 1 : THe above two candidates have been shortlisted for further call by the company/

# %%
RD=ADf.loc[(ADf['Department']=="Research & Development")]

# %%
RD['MonthlyIncome'].mean()
# Out:
# 6630.326086956522

# %%
# Answer 2 : Mean monthly income is 6630.33 (units not specified in the problem)

# %%
ST=ADf.loc[(ADf['Department']=="Sales")]

# %%
Q2= ST.loc[(ST['JobRole']=="Sales Executive")&(ST['PerformanceRating']>=3)&(ST['JobSatisfaction']>=4)&(ST['BusinessTravel']=="Non-Travel")]

# %%
Q2.head(20)
# Out:
#       Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 218    45        No     Non-Travel       1052      Sales                 6
# 241    32        No     Non-Travel        976      Sales                26
# 261    38        No     Non-Travel       1327      Sales                 2
# 358    36        No     Non-Travel        845      Sales                 1
# 442    36        No     Non-Travel        635      Sales                10
# 446    41        No     Non-Travel        267      Sales                10
# 703    38        No     Non-Travel        152      Sales                10
# 708    36        No     Non-Travel       1229      Sales                 8
# 888    35        No     Non-Travel       1212      Sales                 8
# 1198   33        No     Non-Travel        530      Sales                16
# 1447   36        No     Non-Travel        301      Sales                15
#
#       Education    EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %%
Q2.value_counts()
# Out:
# Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  EducationField    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  JobRole          JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
#Q3
Q3=pd.concat([RD,ST])

# %%
RD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 828 entries, 1 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       828 non-null    int64
#  1   Attrition                 828 non-null    object
#  2   BusinessTravel            828 non-null    object
#  3   DailyRate                 828 non-null    int64
#  4   Department                828 non-null    object
#  5   DistanceFromHome          828 non-null    int64
#  6   Education                 828 non-null    int64
#  7   EducationField            828 non-null    object
#  8   EmployeeCount             828 non-null    int64
#  9   EmployeeNumber            828 non-null    int64
#  10  EnvironmentSatisfaction   828 non-null    int64
#  11  Gender                    828 non-null    object
#  12  HourlyRate                828 non-null    int64
#  13  JobInvolvement            828 non-null    int64
# ...

# %%
ST.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 18 to 1468
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       354 non-null    int64
#  1   Attrition                 354 non-null    object
#  2   BusinessTravel            354 non-null    object
#  3   DailyRate                 354 non-null    int64
#  4   Department                354 non-null    object
#  5   DistanceFromHome          354 non-null    int64
#  6   Education                 354 non-null    int64
#  7   EducationField            354 non-null    object
#  8   EmployeeCount             354 non-null    int64
#  9   EmployeeNumber            354 non-null    int64
#  10  EnvironmentSatisfaction   354 non-null    int64
#  11  Gender                    354 non-null    object
#  12  HourlyRate                354 non-null    int64
#  13  JobInvolvement            354 non-null    int64
# ...

# %%
Q3.head()
Q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1182 entries, 1 to 1468
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1182 non-null   int64
#  1   Attrition                 1182 non-null   object
#  2   BusinessTravel            1182 non-null   object
#  3   DailyRate                 1182 non-null   int64
#  4   Department                1182 non-null   object
#  5   DistanceFromHome          1182 non-null   int64
#  6   Education                 1182 non-null   int64
#  7   EducationField            1182 non-null   object
#  8   EmployeeCount             1182 non-null   int64
#  9   EmployeeNumber            1182 non-null   int64
#  10  EnvironmentSatisfaction   1182 non-null   int64
#  11  Gender                    1182 non-null   object
#  12  HourlyRate                1182 non-null   int64
#  13  JobInvolvement            1182 non-null   int64
# ...

# %%
QA3=Q3.loc[(Q3['Education']>=3)]

# %%
QA3.tail(20)
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 1378   42        No      Travel_Rarely        419      Sales
# 1380   35        No      Travel_Rarely        682      Sales
# 1384   34        No      Travel_Rarely        937      Sales
# 1385   34        No      Travel_Rarely       1239      Sales
# 1391   38        No      Travel_Rarely       1404      Sales
# 1392   35        No      Travel_Rarely       1224      Sales
# 1393   27        No      Travel_Rarely        954      Sales
# 1403   39        No      Travel_Rarely        119      Sales
# 1416   38        No      Travel_Rarely       1321      Sales
# 1428   32        No      Travel_Rarely        234      Sales
# 1431   32        No      Travel_Rarely        801      Sales
# 1434   52        No         Non-Travel        585      Sales
# 1439   36        No      Travel_Rarely        557      Sales
# 1446   34        No      Travel_Rarely        704      Sales
# ...
